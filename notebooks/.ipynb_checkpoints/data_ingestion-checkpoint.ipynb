# %% [markdown]
# # Data ingestion

# %% [markdown]
# #### Importing important libraries

# %%
# Import the necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact

# %%
# Specify the absolute file path
file_path = "dataset/air_quality_data.csv"

# %%
# importing dataset and converting data into pandas dataframe
df = pd.read_csv(file_path)

# %% [markdown]
# # About dataset

# %% [markdown]
# <b>Context</b>
# Air Quality plays a significant factor in maintaining the health of an individual. Hence, monitoring the Air Quality by measuring and documenting the concentration levels of different pollutants is important.
#
# <b>Source</b>
# The dataset have been derived from Central Pollution Control Board of India: : https://cpcb.nic.in/
#
# <b>Inspiration</b>
# This dataset aims to document the pollutant concentration levels in different cities of India at different dates and time during the period of 2015 - 2020. The pollutant concentration levels can be utilized to determine Air Quality Index and conclude on the air quality of India throughout the period. The dataset is aimed to be updated annually with up-to-date values and credible information.
#
# Dataset Reference: [click Here](https://www.kaggle.com/datasets/amandeepvasistha/air-quality-data)

# %% [markdown]
# # Data Profiling and Inspection

# %% [markdown]
# # 1. Data Size
# Question: How big data?<br>
# Approach: check the shape of the dataset.<br>
# -- shape returns the number of rows and columns

# %%
df.shape
# Out:
# (737406, 16)

# %% [markdown]
# # 2. Data Preview
# Question: What does the data look like?<br>
# -- head() displays the first few roes of the dataset<br>
# -- sample() displays the randomly selected items rows of the dataset.

# %%
df.head(3)
# Out:
#         City             Datetime  PM2.5  PM10    NO    NO2    NOx  NH3    CO  \
# 0  Ahmedabad  2015-01-01 01:00:00    NaN   NaN  1.00  40.01  36.37  NaN  1.00
# 1  Ahmedabad  2015-01-01 02:00:00    NaN   NaN  0.02  27.75  19.73  NaN  0.02
# 2  Ahmedabad  2015-01-01 03:00:00    NaN   NaN  0.08  19.32  11.08  NaN  0.08
#
#       SO2  O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  122.07 NaN      0.0      0.0     0.0  NaN        NaN
# 1   85.90 NaN      0.0      0.0     0.0  NaN        NaN
# 2   52.83 NaN      0.0      0.0     0.0  NaN        NaN

# %%
df.sample(3)
# Out:
#              City             Datetime  PM2.5    PM10     NO    NO2    NOx  \
# 596746      Patna  2018-03-26 11:00:00  95.25     NaN   2.75   9.76   8.40
# 637340    Talcher  2019-06-29 02:00:00  37.34  103.28  24.51   7.68  32.19
# 381850  Hyderabad  2018-09-14 12:00:00  44.62   87.00   1.85  32.62  18.81
#
#           NH3    CO    SO2     O3  Benzene  Toluene  Xylene    AQI  \
# 596746    NaN  0.74  15.02    NaN     0.35     3.29    0.24  219.0
# 637340   7.54  1.76  24.71   2.15     0.00      NaN     NaN  113.0
# 381850  14.24  0.62   8.36  58.20     2.22    25.71    2.70   79.0
#
#           AQI_Bucket
# 596746          Poor
# 637340      Moderate
# 381850  Satisfactory

# %% [markdown]
# # 3. Data Types
# Question: What types of information are stored in each columns?<br>
# Approach: Check the data types of each column using dtype or info().<br>
# -- info() provides information about the dataset.<br>
# -- dtypes returns the data types of each columns

# %%
# checking datatypes of each colums
df.dtypes
# Out:
# City           object
# Datetime       object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
# dtype: object

# %%
# Overall Information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737406 entries, 0 to 737405
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   City        737406 non-null  object
#  1   Datetime    737406 non-null  object
#  2   PM2.5       587720 non-null  float64
#  3   PM10        429529 non-null  float64
#  4   NO          617192 non-null  float64
#  5   NO2         616699 non-null  float64
#  6   NOx         609997 non-null  float64
#  7   NH3         454536 non-null  float64
#  8   CO          648830 non-null  float64
#  9   SO2         603179 non-null  float64
#  10  O3          604176 non-null  float64
#  11  Benzene     568137 non-null  float64
#  12  Toluene     508758 non-null  float64
#  13  Xylene      263468 non-null  float64
#  14  AQI         603645 non-null  float64
#  15  AQI_Bucket  603645 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 90.0+ MB

# %% [markdown]
# ### From above information
# * Total number of entries have 737406
# * Total number of columns is 16
#     1. PM2.5 has 587720 non null remaining are null value
#     2. PM10 has 429529 non null reamaining are null value
#     3. NO has 617192 non null reamaining are null value
#     4. NO2 has 616699 non null reamaining are null value
#     5. NOx has 609997 non null reamaining are null value
#     6. NH3 has 454536 non null reamaining are null value
#     7. CO has 648830 non null reamaining are null value
#     8. SO2 has 603179 non null reamaining are null value
#     9. Benzene has 568137 non null reamaining are null value
#     10. Toluene has 508758 non null reamaining are null value
#     11. Xylene has 263468  non null reamaining are null value
#     12. AQI has 603645  non null reamaining are null value
#     13. AQI_Bucket has 603645  non null reamaining are null value

# %% [markdown]
# # 4. Missing Values
# Question: Are there any null or missing values in the data?<br>
# Approach: Check for the presence of missing values using isnull() or isna().<br>
# -- isna().sum() or isnull().sum() gives the total number of missing values per column.<br>
# -- isna().mean() * 100 provides the percentage of missing values

# %%
# Checking missing data 
df.isna().sum()
# Out:
# City               0
# Datetime           0
# PM2.5         149686
# PM10          307877
# NO            120214
# NO2           120707
# NOx           127409
# NH3           282870
# CO             88576
# SO2           134227
# O3            133230
# Benzene       169269
# Toluene       228648
# Xylene        473938
# AQI           133761
# AQI_Bucket    133761
# dtype: int64

# %%
# Missing values
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

missing_values= missing_values_table(df)
missing_values.style.background_gradient(cmap='Reds')
# Out:
# Your selected dataframe has 16 columns.
# There are 14 columns that have missing values.
# <style type="text/css">
# #T_3341d_row0_col0, #T_3341d_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_3341d_row1_col0, #T_3341d_row1_col1 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_3341d_row2_col0, #T_3341d_row2_col1 {
#   background-color: #fa6849;
#   color: #f1f1f1;
# }
# #T_3341d_row3_col0, #T_3341d_row3_col1 {
#   background-color: #fc9576;
#   color: #000000;
# }
# #T_3341d_row4_col0, #T_3341d_row4_col1 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_3341d_row5_col0, #T_3341d_row5_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_3341d_row6_col0, #T_3341d_row6_col1, #T_3341d_row7_col0, #T_3341d_row7_col1, #T_3341d_row8_col0, #T_3341d_row8_col1 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_3341d_row9_col0, #T_3341d_row9_col1 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### From above observation
# * Xylene has highest percentage of missing value with 64.27% in original dataset
# * CO has lowest percentage of missing value among others with 12.27% in original dataset

# %% [markdown]
# # 5. Statistical Overview
# Question: How is the data distributed statistically?<br>
# Approach: Check statistical measures using describe()<br>
# -- describe() gives statistical measures for numerical columns.

# %%
# Descritive statistice
df.describe().transpose()
# Out:
#             count        mean         std   min    25%     50%     75%  \
# PM2.5    587720.0   67.615679   74.331004  0.01  26.29   46.50   79.50
# PM10     429529.0  119.035184  103.678358  0.01  52.54   91.71  147.65
# NO       617192.0   17.428187   31.758813  0.01   3.90    8.04   16.33
# NO2      616699.0   28.871505   28.980321  0.01  10.85   20.38   36.42
# NOx      609997.0   32.288461   39.452857  0.00  10.73   20.90   37.28
# NH3      454536.0   23.602700   28.705890  0.01   8.14   15.39   29.27
# CO       648830.0    2.186294   10.830938  0.00   0.42    0.81    1.37
# SO2      603179.0   14.059323   19.257355  0.01   4.91    8.40   14.80
# O3       604176.0   34.785994   29.509072  0.01  13.65   26.48   47.50
# Benzene  568137.0    3.095727   16.429980  0.00   0.06    0.87    2.77
# Toluene  508758.0    8.662618   21.669094  0.00   0.37    2.61    8.44
# Xylene   263468.0    3.127918    7.775396  0.00   0.10    0.80    3.14
# ...

# %%
# Descritive statistice
df.describe(include="object").transpose()
# Out:
#              count unique         top    freq
# City        737406     26   Ahmedabad   50201
# Datetime    737406  50201  2020-07-01      26
# AQI_Bucket  603645      6    Moderate  207820

# %% [markdown]
# -- Central Tendency: This term refers to values located at the data's central position or middle zone.<br>
# The three generally estimated parameters of central tendency are mean, median, and mode.<br>
# -- Mean is the average of all values in data.<br>
# -- While the mode is the values that occurs the maximum number of times.<br>
# -- The Medain is the middle value with equal observations to its left and right.

# %% [markdown]
# ### From above observation
# * AQI has highest mean with maximum value 3133 and minimum value 8.
# * CO has lowest mean with maximum value 498.57 and minimum value 0.
# * PM10 has 119.03 mean with maximum value 1000 and minimum value 0.01.
# * PM2.5 has 67.61 mean with maximum value 999.99 and minimum vale 0.01.
# * Moderate has highest frequency with 207820 in AQI_Bucket column <br>
# So on

# %% [markdown]
# # 6. Data Skewness
# Question: How is the data distributed are skewed?<br>
# Approach: Check skewness of data using skew().<br>
# -- skew() return skew value pf numerical features.

# %%
numerical_features = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
       'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI']

# %%
# checking the skew of numerical features
df[numerical_features].skew()
# Out:
# PM2.5       4.283556
# PM10        2.498362
# NO          5.383978
# NO2         3.326041
# NOx         3.672102
# NH3         5.212583
# CO         20.851482
# SO2         4.424654
# O3          1.694459
# Benzene    22.468028
# Toluene    11.504695
# Xylene     13.586556
# AQI         6.305913
# dtype: float64

# %% [markdown]
# # From above observation
# * All the columns has positively skewed distribution that means mean is greater than medain in each columns

# %% [markdown]
# # 7. Duplicated Data
# Question: Are there duplicate value?<br>
# Approach: Identify duplicate using duplicated().<br>
# -- duplicated().sum() counts the number of duplicate rows.

# %%
# checking duplicated value
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # From above observation
# * There is no any duplicated value in this dataset.

# %% [markdown]
# # 8. Correlation Analysis
# Question: How are different columns related to each other? <br>
# Approach: Examine the correlation matrix and visualize it if needed.<br>
# -- corr() calculate the correlation matrix
# -- heatmap() visualize the correlation matrix

# %%
# calculating the correlation
df.corr(numeric_only=True)
# Out:
#             PM2.5      PM10        NO       NO2       NOx       NH3        CO  \
# PM2.5    1.000000  0.810258  0.372490  0.304860  0.387089  0.244341  0.082974
# PM10     0.810258  1.000000  0.441263  0.431134  0.482848  0.344766  0.101421
# NO       0.372490  0.441263  1.000000  0.435492  0.802005  0.170527  0.318198
# NO2      0.304860  0.431134  0.435492  1.000000  0.618809  0.217349  0.271829
# NOx      0.387089  0.482848  0.802005  0.618809  1.000000  0.161921  0.277771
# NH3      0.244341  0.344766  0.170527  0.217349  0.161921  1.000000  0.108077
# CO       0.082974  0.101421  0.318198  0.271829  0.277771  0.108077  1.000000
# SO2      0.125238  0.232386  0.131319  0.307913  0.181156 -0.011395  0.284842
# O3       0.050387  0.117720 -0.103012  0.065800 -0.072262  0.050083 -0.047227
# Benzene  0.033784  0.034877  0.071242  0.050680  0.073887 -0.007835  0.068327
# Toluene  0.128167  0.185583  0.193959  0.273605  0.227904  0.024173  0.244104
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### From above correlation matrix
# * Most of the columns are positively correlated with each other

# %% [markdown]
# # 9. Exploring Diversity
# Question: How may unique value are there in a specific column?<br>
# Approach: Use nunique() methods to find the number of unique values in a particular column.<br>
# -- nunique() method returns the number of unique values for each columns.

# %%
#  Checking the unique values in columns AQI_Bucket
df["AQI_Bucket"].nunique()
# Out:
# 6

# %% [markdown]
# ### From above observation
# * AQI_Bucket column has total 6 unique values.

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # 1. Univariate Analysis
# * Its refers to the examination and exploration of a single variable in a dataset.
# * It  involves the distribution summary statistic, visualization (eg: histogram, box plot) and understaing the distribution and characteristics of that specific variable

# %% [markdown]
# #### AQI_Bucket
# Question: Explore the distribution of AQI_Bucket.<br>
# Approach: Visualized the distribution of AQI_Bucket (categorical data) using pie().<br>
# -- plt.pie() visualized the value counts of single classes in a column.<br>

# %%
# calculating the value counts
aqi_bucket = df["AQI_Bucket"].value_counts()

# visualizing  in pie chart
plt.figure(figsize=(10,10))
plt.pie(x=aqi_bucket.values, labels=aqi_bucket.index, autopct="%.2f%%")
plt.grid()
plt.show()

# %% [markdown]
# ### From above observation,
# * Moderate has highest counts value with around 34.43% of data in this dataset.
# * Satisfactory has counts value with around 32.74% of data in this dataset.
# * Severe has lowest counts value with arount 4.80% of data in this dataset.
# * Remaining Poor, Very Poor and Good has around 5% to 12% of data in this dataset.

# %% [markdown]
# ### City
# Qustion: Exploring the distribution of City.<br>
# Approach: Visualizing the distribution of City(categorical data) using countplot().<br>
# -- sns.countplot() compute counts and visualized the counts values of each classes. <br>

# %%
# visualizing in countplot
plt.figure(figsize=(10,10))
plt.title("Countplot of City")
sns.countplot(df["City"])
plt.show()

# %% [markdown]
# ### From above observation,
# * City like Ahmedabad, Delhi, Mumbai, Bangaluru, Lucknow, Chennai, Hydrabad and Patna has highest percentage of data in this dataset
# * City like Chadigarh, Bhopal, Kochi, Emakulam and Aizawi has lowest percentage of data in this dataset.

# %% [markdown]
# ### PM2.5
# Question: Exploring the distribuiton of PM2.5.<br>
# Approach: Visualizing the distribution of PM2.5 numerical data using displot().<br>
# -- sns.displot() visualize the numerical data distribution.<br>

# %%
# visualization of PM2.5 using sns.displot()
sns.displot(data=df["PM2.5"], kde=True)
plt.show()

# %% [markdown]
# ### From above observation
# * Distribution of PM2.5 seems to be right tail which means mean is greater tha median

# %% [markdown]
# ### NO
# Question: Exploring the distribuiton of NO.<br>
# Approach: Visualizing the distribution of NO numerical data using displot().<br>
# -- sns.displot() visualize the numerical data distribution.<br>

# %%
# visualization of PM2.5 using sns.displot()
sns.displot(data=df["NO"], kde=True)
plt.show()

# %% [markdown]
# ### From above observation
# * Distribution of NO seems to be right tail which means mean is greater tha median

# %% [markdown]
# ### AQI
# Question: Exploring the distribuiton of AQI.<br>
# Approach: Visualizing the distribution of AQI numerical data using displot().<br>
# -- sns.displot() visualize the numerical data distribution.<br>

# %%
## Display displot for our AQI
sns.displot(data=df["AQI"], kde=True)
plt.show()

# %% [markdown]
# ### From above observation
# * Distribution of AQI seems to be right tail which means mean is greater tha median

# %% [markdown]
# ### Spereating numerical and categorical data

# %%
numerical_features = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
       'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI']
categorical_features= ['City','AQI_Bucket']

# %% [markdown]
# # Creating an interactive plot for the each features

# %%
## numerical data
@interact(predictor=numerical_features)
def interactive_bivariate_barplot(predictor):
    sns.displot(x=predictor,data=df,kde=True,height=6, color="purple")
# Out:
# interactive(children=(Dropdown(description='predictor', options=('PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', '…

# %% [markdown]
# ### Here is the distribution plot of all numerical data

# %% [markdown]
# # 2. Bi/Multi-variate Analysis
# * Its refers to the examination and exploration of a two or more variable in a dataset.
# The main three types we will see here are:
#     * Numerical VS Numerical
#     * Categorical VS Numerical
#     * Categorical VS Categorical

# %% [markdown]
# ##### Here target variable is <b>AQI</b> for <b>regression</b> and <b>AQI_Bucket</b> for <b>classification.</b>

# %% [markdown]
# ### Distribution of data with target variable "AQI_Bucket"

# %% [markdown]
# ### PM2.5 VS PM10 VS AQI_Bucket
# Question: What is the distribution of PM2.5 VS PM10 VS AQI_Bucket(numerical Vs categorical)?<br>
# Approach: Visualizing the distribution of PM2.5 VS PM10 VS AQI_Bucket using scatterplot().<br>
# -- sns.scatterplot() visualize the distribution of data of give variables. <br>

# %%
sns.scatterplot(x=df["PM2.5"], y=df["PM10"], hue=df["AQI_Bucket"])
plt.show()
# Out:
# C:\Users\Thinkpad\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### From above obseravation
# * Most of the data are scatter between 0 to 1000 of PM10 and 0 to 800 of PM2.5 with respect to AQI_Bucket.

# %% [markdown]
# ### NO VS NO2 VS AQI_Bucket
# Question: What is the distribution of NO VS NO2 VS AQI_Bucket(numerical Vs categorical)?<br>
# Approach: Visualizing the distribution of NO VS NO2 VS AQI_Bucket using scatterplot().<br>
# -- sns.scatterplot() visualize the distribution of data of give variables. <br>

# %%
sns.scatterplot(x=df["NO"], y=df["NO2"], hue=df["AQI_Bucket"])
plt.show()
# Out:
# C:\Users\Thinkpad\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### From above obseravation
# * Most of the data are scatter between 0 to 400 of NO2 and  0 to 500 of NO with respect to AQI_Bucket.

# %% [markdown]
# ### City VS AQI_Bucket
# Question: What is the distribution of City VS AQI_Bucket(numerical Vs categorical)?<br>
# Approach: Visualizing the distribution of City VS AQI_Bucket using barplot().<br>
# -- sns.barplot() visualize the distribution of categorical data. <br>

# %%
df.groupby(["City","AQI_Bucket"]).size().unstack()
# Out:
# AQI_Bucket            Good  Moderate     Poor  Satisfactory   Severe  \
# City
# Ahmedabad             76.0    6744.0   6405.0        1310.0  11556.0
# Aizawl              1965.0       NaN      NaN         674.0      NaN
# Amaravati           4385.0    5595.0   1179.0        8865.0      NaN
# Amritsar            2257.0   10794.0   1571.0       10873.0    164.0
# Bengaluru           4356.0   13381.0   1821.0       27641.0    105.0
# Bhopal               188.0    4122.0    786.0        1632.0      NaN
# Brajrajnagar         503.0   10010.0   2743.0        2399.0      NaN
# Chandigarh          1321.0    2000.0    501.0        3464.0      NaN
# Chennai              738.0   17894.0   3199.0       24098.0    209.0
# Coimbatore          1113.0     526.0      NaN        6315.0      NaN
# Delhi                504.0   12742.0  12985.0        4318.0   6191.0
# Ernakulam              4.0    1418.0      NaN        2085.0      NaN
# ...

# %%
# distribution of City Vs AQI_Bucket uisng barplot
sns.barplot(data=df.groupby(["City","AQI_Bucket"]).size().unstack())
# Out:
# <Axes: xlabel='AQI_Bucket'>

# %% [markdown]
# ### From above observation
# * Each bar represents the count of occurrences for each AQI bucket category within a specific city. This visualization helps in understanding how air quality varies across different cities and the prevalence of different AQI bucket categories within each city.

# %% [markdown]
# ### SO2 VS AQI_Bucket
# Question: What is the disrtibution of SO2 and target variable AQI_Bucket?<br>
# Approach: Visualizing the distribution plot of SO2 and AQI_Bucket using boxplot().<br>
# -- sns.boxplot() compares the distribution of a numerical variabel with different categories.<br>

# %%
# visualizing SO2 vs AQI_Bucket usnig boxplot
sns.boxplot(x="AQI_Bucket", y="SO2", data=df)
# Out:
# <Axes: xlabel='AQI_Bucket', ylabel='SO2'>

# %% [markdown]
# ### From above observation
# * Variation, outlier and overall spread of SO2 with AQI_Bucket has been visualized.
# * Satisfactory and Good has been seen outliers in this dataset.

# %% [markdown]
# ### O3 VS AQI_Bucket
# Question: What is the disrtibution of O3 and target variable AQI_Bucket?<br>
# Approach: Visualizing the distribution plot of O3 and AQI_Bucket using boxplot().<br>
# -- sns.boxplot() compares the distribution of a numerical variabel with different categories.<br>

# %%
# visualizing O3 vs AQI_Bucket usnig boxplot
sns.boxplot(hue="AQI_Bucket", y="O3", data=df)
# Out:
# <Axes: ylabel='O3'>

# %% [markdown]
# ### From above observation
# * Variation, outlier and overall spread of O3 with AQI_Bucket has been visualized.
# * In all class in AQI_Bucket has been seen outliers in this dataset.

# %% [markdown]
# ### Distribution of data with target variable "AQI"

# %% [markdown]
# ### PM2.5 VS AQI
# Question: What is the distribution of PM2.5 VS AQI?<br>
# Approach: Visualizing the distribution of PM2.5 VS AQI using scatterplot().<br>
# -- sns.scatterplot() visualize the distribution of data of give variables. <br>

# %%
## visualizing distirbution of PM2.5 vs AQI
sns.scatterplot(x="PM2.5",y="AQI",data=df)
plt.show()

# %% [markdown]
# ### From above observation
# * When PM2.5 increase the AQI has decreases
# * AQI has high value when PM2.5 value is between 0 to 250

# %% [markdown]
# ### NH3 VS AQI
# Question: What is the distribution of NH3 VS AQI?<br>
# Approach: Visualizing the distribution of NH3 VS AQI using scatterplot().<br>
# -- sns.scatterplot() visualize the distribution of data of give variables. <br>

# %%
## visualizing distirbution of PM2.5 vs AQI
sns.scatterplot(x="NH3",y="AQI",data=df)
plt.show()

# %% [markdown]
# ### From above observation
# * When NH3 increase the AQI has also decreases
# * AQI has high value when NH3 valus is between 0 to 150

# %% [markdown]
# ### City VS PM2.5
# Question: Which city has higest PM2.5 in this dataset? <br>
# Approach: Visualize the mean() of PM2.5 of every city using groupby().<br>
# -- dataframe.groupby() to split a DataFrame into groups based on some criteria, such as a column's unique values.<br>

# %%
# city VS PM2.5
df.groupby(["City"])["PM2.5"].mean().sort_values(ascending=False)
# Out:
# City
# Patna                 121.260595
# Delhi                 117.646494
# Gurugram              114.563000
# Lucknow               110.001035
# Ahmedabad              67.297961
# Brajrajnagar           66.337151
# Kolkata                64.732716
# Jorapokhar             63.985541
# Talcher                63.788131
# Guwahati               61.856476
# Jaipur                 54.713699
# Amritsar               54.558829
# Bhopal                 50.518134
# Chennai                50.210232
# Visakhapatnam          47.811569
# Hyderabad              47.049693
# Chandigarh             41.237403
# Amaravati              38.468085
# Bengaluru              35.587928
# Mumbai                 35.479680
# Kochi                  32.001181
# Coimbatore             29.368217
# Thiruvananthapuram     28.763176
# Shillong               27.357316
# Ernakulam              25.203374
# Aizawl                 19.251520
# Name: PM2.5, dtype: float64

# %% [markdown]
# ### City VS NH3
# Question: Which city has higest NH3 in this dataset? <br>
# Approach: Visualize the mean() of NH3 of every city using groupby().<br>
# -- dataframe.groupby() to split a DataFrame into groups based on some criteria, such as a column's unique values.<br>

# %%
# city VS NH3
df.groupby(["City"])["NH3"].mean().sort_values(ascending=False)
# Out:
# City
# Chennai               62.978177
# Delhi                 42.122816
# Brajrajnagar          35.730518
# Chandigarh            31.843072
# Lucknow               29.553920
# Gurugram              26.655076
# Jaipur                26.615914
# Aizawl                22.325110
# Bengaluru             21.615341
# Ernakulam             20.143510
# Bhopal                19.103946
# Kolkata               18.412857
# Patna                 18.366866
# Hyderabad             16.030602
# Amritsar              14.302595
# Mumbai                13.825501
# Amaravati             12.081051
# Talcher               11.337356
# Coimbatore            11.155639
# Visakhapatnam         10.989257
# Guwahati              10.883633
# Kochi                  8.341250
# Jorapokhar             7.008951
# Thiruvananthapuram     5.070197
# Shillong               2.820361
# Ahmedabad                   NaN
# Name: NH3, dtype: float64

# %% [markdown]
# # Creating an interactive plot for the each features

# %%
numerical_features = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
       'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']
categorical_features= ['City']

# %%
# visualizing numerical features vs AQI usnig scatterplot
@interact(predictor=numerical_features)
def interactive_bivariate_barplot(predictor):
    sns.scatterplot(x=predictor,y="AQI", data=df,color="purple")
# Out:
# interactive(children=(Dropdown(description='predictor', options=('PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', '…

# %% [markdown]
# # Here is the all numerical features scatter distribution plot with target variable AQI

# %%
# visualizing numerical features vs AQI_Bucket usnig boxplot
@interact(predictor=numerical_features)
def interactive_bivariate_barplot(predictor):
    plt.figure(figsize=(10,10))
    sns.boxplot(x=predictor,hue="AQI_Bucket", data=df,color="purple")
    plt.show()
# Out:
# interactive(children=(Dropdown(description='predictor', options=('PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', '…

# %% [markdown]
# # Here is the all numerical features box distribution plot with target variable AQI_Bucket

# %% [markdown]
# # Data Preparation and Feature Engineering

# %% [markdown]
# ### Types of feature in our dataframe

# %%
df.dtypes
# Out:
# City           object
# Datetime       object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
# dtype: object

# %%
df["Datetime"].sample(5)
# Out:
# 509501    2018-11-10 16:00:00
# 277523    2018-09-10 00:00:00
# 176492    2020-01-16 13:00:00
# 517391    2019-10-05 10:00:00
# 579988    2016-04-27 05:00:00
# Name: Datetime, dtype: object

# %% [markdown]
# ### Changing columns which is object to Date Time
# Question: why datetime cannot be object datatype? if object then need to change to datetime datatype.<br>
# Approach: Change datetime object into datetime datatypes using to_datetime().<br>
# -- to_datetime() convert object into datetime datetypes. <br>

# %%
df["Datetime"] = pd.to_datetime(df["Datetime"], format='ISO8601')

# %% [markdown]
# ## Visualising yearly data:
# Question: How the pollutants has been distributing over the year?<br>
# Approach: Visualizing the pollutants that has been distributing over the year dataframe.plot().<br>
# -- dataframe.plot() visualize the distribution of specific variable. <br>

# %%
city_day = df.copy()
pollutants = ['PM2.5','PM10','NO2', 'CO', 'SO2','O3', 'Benzene','Toluene','Xylene']
city_day.set_index('Datetime',inplace=True)
axes = city_day[pollutants].plot(marker='.', alpha=0.5, linestyle='None', figsize=(16, 20), subplots=True)
for ax in axes:
    
    ax.set_xlabel('Years')
    ax.set_ylabel('ug / m3')

# %% [markdown]
# ### Adding new columns after converting datetimes datetypes

# %%
df["Year"] = df["Datetime"].dt.year
df["Month"] = df["Datetime"].dt.month
df["Day"] = df["Datetime"].dt.day
df["Hour"] = df["Datetime"].dt.hour
df["Minute"] = df["Datetime"].dt.minute
df["Second"] = df["Datetime"].dt.second

# %%
df.sample(3)
# Out:
#              City            Datetime  PM2.5    PM10     NO    NO2    NOx  \
# 313471   Gurugram 2017-10-04 22:00:00    NaN     NaN    NaN    NaN  23.11
# 75244    Amritsar 2017-05-04 16:00:00  61.05   78.42  12.58  16.75    NaN
# 377362  Hyderabad 2018-03-11 12:00:00  52.79  114.85   1.42  26.14  16.16
#
#           NH3    CO   SO2  ...  Toluene  Xylene    AQI  AQI_Bucket  Year  \
# 313471    NaN  0.00   NaN  ...      NaN     NaN  204.0        Poor  2017
# 75244   30.07  0.00  5.79  ...      NaN     NaN  101.0    Moderate  2017
# 377362  17.10  0.72  6.64  ...     4.12    0.93  125.0    Moderate  2018
#
#        Month  Day  Hour  Minute  Second
# 313471    10    4    22       0       0
# 75244      5    4    16       0       0
# 377362     3   11    12       0       0
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Droping the Datetime column

# %%
df.drop(columns="Datetime", inplace=True)

# %%
df.head(3)
# Out:
#         City  PM2.5  PM10    NO    NO2    NOx  NH3    CO     SO2  O3  ...  \
# 0  Ahmedabad    NaN   NaN  1.00  40.01  36.37  NaN  1.00  122.07 NaN  ...
# 1  Ahmedabad    NaN   NaN  0.02  27.75  19.73  NaN  0.02   85.90 NaN  ...
# 2  Ahmedabad    NaN   NaN  0.08  19.32  11.08  NaN  0.08   52.83 NaN  ...
#
#    Toluene  Xylene  AQI  AQI_Bucket  Year  Month  Day  Hour  Minute  Second
# 0      0.0     0.0  NaN         NaN  2015      1    1     1       0       0
# 1      0.0     0.0  NaN         NaN  2015      1    1     2       0       0
# 2      0.0     0.0  NaN         NaN  2015      1    1     3       0       0
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Visualizing the impact of year, month, day, hour, minute and second with target value AQI for regression
# Question: What is the relationship between datetime with target variable AQI for regression?<br>
# Approach: Visualize the correlation between datetime with AQI using .corr().<br>
# -- .corr() visualize the correlation matrix of numerical features.<br>

# %%
datatime = ["Year", "Month", "Day", "Hour", "Minute", "Second"]
df[datatime + ["AQI"]].corr()
# Out:
#             Year     Month       Day      Hour  Minute  Second       AQI
# Year    1.000000 -0.203478 -0.001609 -0.000209     NaN     NaN -0.164007
# Month  -0.203478  1.000000  0.009268 -0.000064     NaN     NaN  0.018774
# Day    -0.001609  0.009268  1.000000  0.000144     NaN     NaN -0.006242
# Hour   -0.000209 -0.000064  0.000144  1.000000     NaN     NaN -0.013628
# Minute       NaN       NaN       NaN       NaN     NaN     NaN       NaN
# Second       NaN       NaN       NaN       NaN     NaN     NaN       NaN
# AQI    -0.164007  0.018774 -0.006242 -0.013628     NaN     NaN  1.000000

# %% [markdown]
# ### From above observation
# * If the columns 'Day', and 'Hour' have negative correlations and 'Minute' and 'Second' has NaN with AQI variables and are not providing meaningful information for  analysis or modeling, so, it is be safe to drop them.

# %% [markdown]
# ### Visualizing the impact of year, month, day, hour, minute and second with target value AQI_Bucket for classification
# Question: What is the relationship between datetime with target variable AQI_Bucket for Classification?<br>
# Approach: Visualize the correlation between datetime with AQI_Bucket using .corr().<br>
# -- .corr() visualize the correlation matrix of numerical features.<br>

# %% [markdown]
# ### At first converting target variable to numerical using LabelEncoder()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
aqi_bucket_labelencoder = le.fit_transform(df["AQI_Bucket"])

# %%
aqi_bucket = df.copy()
aqi_bucket["AQI_Bucket"] = aqi_bucket_labelencoder
datatime = ["Year", "Month", "Day", "Hour", "Minute", "Second"]
aqi_bucket[datatime + ["AQI","AQI_Bucket"]].corr()
# Out:
#                 Year     Month       Day      Hour  Minute  Second       AQI  \
# Year        1.000000 -0.203478 -0.001609 -0.000209     NaN     NaN -0.164007
# Month      -0.203478  1.000000  0.009268 -0.000064     NaN     NaN  0.018774
# Day        -0.001609  0.009268  1.000000  0.000144     NaN     NaN -0.006242
# Hour       -0.000209 -0.000064  0.000144  1.000000     NaN     NaN -0.013628
# Minute           NaN       NaN       NaN       NaN     NaN     NaN       NaN
# Second           NaN       NaN       NaN       NaN     NaN     NaN       NaN
# AQI        -0.164007  0.018774 -0.006242 -0.013628     NaN     NaN  1.000000
# AQI_Bucket -0.271193  0.025133 -0.004532 -0.002727     NaN     NaN  0.410120
#
#             AQI_Bucket
# Year         -0.271193
# Month         0.025133
# Day          -0.004532
# Hour         -0.002727
# Minute             NaN
# Second             NaN
# AQI           0.410120
# AQI_Bucket    1.000000

# %% [markdown]
# ### From above observation
# * If the columns 'Day', and 'Hour' have negative correlations and 'Minute' and 'Second' has NaN with also AQI_Bucket variables and are not providing meaningful information for analysis or modeling, so, it is be safe to drop them.

# %% [markdown]
# ### Droping column 'Day', 'Hour','Minute' and 'Second'

# %%
df.drop(columns=['Day', 'Hour','Minute','Second'], inplace=True)
df.sample(4)
# Out:
#              City  PM2.5    PM10    NO    NO2    NOx    NH3    CO   SO2  \
# 203537    Chennai  67.73     NaN  6.75  28.56  15.24    NaN  0.00  7.54
# 24620   Ahmedabad  63.20     NaN   NaN    NaN  73.43    NaN   NaN   NaN
# 124531  Bengaluru   8.49   78.65  8.10  31.49   0.00  23.69  0.65  4.21
# 386567  Hyderabad  64.40  150.19  3.41  45.00  26.71  17.60  0.95  7.34
#
#            O3  Benzene  Toluene  Xylene    AQI AQI_Bucket  Year  Month
# 203537  76.24     0.60     0.28     NaN  250.0       Poor  2016     10
# 24620     NaN     7.45    14.96    0.98  108.0   Moderate  2017     10
# 124531   7.51     1.48     0.63     NaN   50.0       Good  2017      6
# 386567  28.57     2.48    14.40    3.30  131.0   Moderate  2019      3

# %% [markdown]
# ## Handling missing values

# %% [markdown]
# Question: How to handlde missing pattern and replace with appropate values?<br>
# Approach: Handle missing values by finding the patterns with the help of year and month and replace using medain values with the help of .fillna(medain).<br>
# -- fillna(medain) fill the missing values with medain

# %% [markdown]
# #### handling missing values of PM2.5

# %%
def fill_pm_2_5(df):
    df4 = df.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["PM2.5"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["PM2.5"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "PM2.5"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "PM2.5"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %%
df_filled.loc[df_filled["PM2.5"].isna()
# Out:
#                  City  PM2.5  PM10  NO  NO2  NOx   NH3   CO  SO2  O3  Benzene  \
# 8015        Ahmedabad    NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN NaN      NaN
# 8016        Ahmedabad    NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN NaN      NaN
# 8017        Ahmedabad    NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN NaN      NaN
# 8018        Ahmedabad    NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN NaN      NaN
# 8019        Ahmedabad    NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN NaN      NaN
# ...               ...    ...   ...  ..  ...  ...   ...  ...  ...  ..      ...
# 736396  Visakhapatnam    NaN   NaN NaN  NaN  0.0  1.37  0.0  NaN NaN      0.0
# 736397  Visakhapatnam    NaN   NaN NaN  NaN  0.0  7.61  0.0  NaN NaN      0.0
# 736398  Visakhapatnam    NaN   NaN NaN  NaN  0.0  0.21  0.0  NaN NaN      0.0
# 736399  Visakhapatnam    NaN   NaN NaN  NaN  0.0  0.21  0.0  NaN NaN      0.0
# 736400  Visakhapatnam    NaN   NaN NaN  NaN  0.0  0.24  0.0  NaN NaN      0.0
#
# ...

# %% [markdown]
# #### handling missing values of PM10

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["PM10"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["PM10"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "PM10"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "PM10"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values of NO

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["NO"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["NO"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "NO"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "PM10"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values of NO2

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["NO2"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["NO2"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "NO2"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "NO2"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values of NOx

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["NOx"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["NOx"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "NOx"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "NOx"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values of NH3

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["NH3"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["NH3"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "NH3"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "NOx"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values of CO

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["CO"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["CO"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "CO"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "CO"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values of SO2

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["SO2"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["SO2"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "SO2"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "SO2"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values of O3

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["O3"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["O3"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "O3"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "O3"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values Benzene

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["Benzene"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["Benzene"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "Benzene"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "Benzene"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values of Toluene

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["Toluene"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["Toluene"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "Toluene"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "Toluene"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values of Xylene

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["Xylene"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["Xylene"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "Xylene"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "Xylene"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values of AQI

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["AQI"].isnull().all():  # Check if all values in the slice are NaN
                    median = slice_df["AQI"].median()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "AQI"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "AQI"].fillna(median)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# #### handling missing values of "AQI_Bukcet"

# %%
def fill_pm_2_5(df):
    df4 = df_filled.copy()  # Create a copy of the DataFrame to avoid modifying the original
    for city_item in df4["City"].unique():
        for year_item in df4["Year"].unique():
            for month_item in df4["Month"].unique():
                slice_df = df4[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item)]
                if not slice_df["AQI_Bucket"].isnull().all():  # Check if all values in the slice are NaN
                    mode = slice_df["AQI_Bucket"].mode()
                    df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "AQI_Bucket"] = df4.loc[(df4["City"]==city_item) & (df4["Year"]==year_item) & (df4["Month"]==month_item), "AQI_Bucket"].fillna(mode)
    return df4

# Call the function passing your DataFrame 'df' as an argument
df_filled = fill_pm_2_5(df)

# %% [markdown]
# ## Still dataset presence missing values after handling with median by finding pattern with year and month. Those missing values are safe to drop.

# %%
# null values after handling missing value
df_filled.isna().sum()
# Out:
# City               0
# PM2.5          81084
# PM10          242943
# NO             52037
# NO2            52860
# NOx            78710
# NH3           225398
# CO             18227
# SO2            51335
# O3             55040
# Benzene       102778
# Toluene       169749
# Xylene        426822
# AQI            68615
# AQI_Bucket    133761
# Year               0
# Month              0
# dtype: int64

# %%
# null value in original data
df.isna().sum()
# Out:
# City               0
# PM2.5         149686
# PM10          307877
# NO            120214
# NO2           120707
# NOx           127409
# NH3           282870
# CO             88576
# SO2           134227
# O3            133230
# Benzene       169269
# Toluene       228648
# Xylene        473938
# AQI           133761
# AQI_Bucket    133761
# Year               0
# Month              0
# dtype: int64

# %%
df["AQI_Bucket"].mode()

# %%
columns_to_check = ["PM2.5", "PM10", "NO", "NO2", "NOx", "NH3", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI", "AQI_Bucket"]

# Drop rows where any of the specified columns contain missing values
df_dropped = df.drop(df[df[columns_to_check].isna().all(axis=1)].index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[184], line 2
#       1 value= ["PM2.5","PM10","NO","NO2","NOx","NH3","CO","SO2","O3","Benzene","Toluene","Xylene","AQI","AQI_Bucket"]
# ----> 2 df.loc[df["PM2.5"]['PM10'].isna()]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
# ...

# %%
columns_to_check = ["PM2.5", "PM10", "NO", "NO2", "NOx", "NH3", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI", "AQI_Bucket"]
df[df[columns_to_check].isna().all(axis=1).index]

# %%
columns_to_check = ["PM2.5", "PM10", "NO", "NO2", "NOx", "NH3", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI", "AQI_Bucket"]
df[df[columns_to_check].isna().all(axis=0).index]
